# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
df= pd.read_csv('bank-additional-full.csv',sep=';')

# %%
df.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (41199, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
#  17  cons.conf.idx   41196 non-null  float64
#  18  euribor3m       41196 non-null  float64
#  19  nr.employed     41196 non-null  float64
#  20  y               41196 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 6.6+ MB

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41195.000000  41196.000000  41196.000000  41196.000000  41196.000000
# mean      40.030319    258.281265      2.567676    962.482547      0.173124
# std       10.431818    259.254211      2.769751    186.893451      0.494987
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41196.000000    41195.000000   41196.000000  41196.000000  41196.000000
# mean       0.081656       93.575867     -40.504600      3.620787   5166.996405
# std        1.570894        0.578999       4.629972      1.734655     72.300104
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
df.isnull().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
# impute
# drop

# %%
round(df.isnull().sum() / len(df) *100,2)   # null percentage
# Out:
# age               0.01
# job               0.01
# marital           0.01
# education         0.01
# default           0.01
# housing           0.01
# loan              0.01
# contact           0.01
# month             0.01
# day_of_week       0.01
# duration          0.01
# campaign          0.01
# pdays             0.01
# previous          0.01
# poutcome          0.01
# emp.var.rate      0.01
# cons.price.idx    0.01
# cons.conf.idx     0.01
# euribor3m         0.01
# nr.employed       0.01
# y                 0.01
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# outliers

# %%
col_list = df.columns

# %%
col_list
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
for i in col_list:
    
    if df[i].dtype!='object':
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
df.pdays.value_counts()
# Out:
# 999.0    39662
# 3.0        439
# 6.0        412
# 4.0        118
# 9.0         64
# 2.0         61
# 7.0         60
# 12.0        58
# 10.0        52
# 5.0         46
# 13.0        36
# 11.0        28
# 1.0         26
# 15.0        24
# 14.0        20
# 8.0         18
# 0.0         15
# 16.0        11
# 17.0         8
# 18.0         7
# 22.0         3
# 19.0         3
# 21.0         2
# 25.0         1
# 26.0         1
# 27.0         1
# 20.0         1
# Name: pdays, dtype: int64

# %%
df.previous.value_counts()
# Out:
# 0.0    35551
# 1.0     4562
# 2.0      754
# 3.0      216
# 4.0       70
# 5.0       18
# 6.0        5
# 7.0        1
# Name: previous, dtype: int64

# %%
out_cols=['age','campaign','cons.conf.idx','duration']

# %%
for col in out_cols:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    
    IQR=Q3-Q1
    
    lower=Q1-1.5*IQR
    upper=Q3+1.5*IQR
    
    df=df[(df[col]>=lower) & (df[col]<=upper)]

# %%
for i in df.columns:
    
    if df[i].dtype!='object':
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35191 entries, 0 to 41186
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             35191 non-null  float64
#  1   job             35191 non-null  object
#  2   marital         35191 non-null  object
#  3   education       35191 non-null  object
#  4   default         35191 non-null  object
#  5   housing         35191 non-null  object
#  6   loan            35191 non-null  object
#  7   contact         35191 non-null  object
#  8   month           35191 non-null  object
#  9   day_of_week     35191 non-null  object
#  10  duration        35191 non-null  float64
#  11  campaign        35191 non-null  float64
#  12  pdays           35191 non-null  float64
#  13  previous        35191 non-null  float64
#  14  poutcome        35191 non-null  object
#  15  emp.var.rate    35191 non-null  float64
#  16  cons.price.idx  35191 non-null  float64
#  17  cons.conf.idx   35191 non-null  float64
#  18  euribor3m       35191 non-null  float64
#  19  nr.employed     35191 non-null  float64
#  20  y               35191 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 6.9+ MB

# %%
df.job.value_counts()
# Out:
# admin.           8998
# blue-collar      8051
# technician       5823
# services         3440
# management       2514
# entrepreneur     1261
# self-employed    1213
# retired          1100
# housemaid         893
# unemployed        868
# student           757
# unknown           273
# Name: job, dtype: int64

# %%
# Encoding......Label encoding


obj_cols = []

for col in df.columns:
    if df[col].dtype=='object' :
        obj_cols.append(col)

# %%
obj_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in obj_cols:
    df[col]=le.fit_transform(df[col])

# %%
df.job.value_counts()
# Out:
# 0     8998
# 1     8051
# 9     5823
# 7     3440
# 4     2514
# 2     1261
# 6     1213
# 5     1100
# 3      893
# 10     868
# 8      757
# 11     273
# Name: job, dtype: int64

# %%
df.housing.value_counts()
# Out:
# 2    18480
# 0    15862
# 1      849
# Name: housing, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35191 entries, 0 to 41186
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             35191 non-null  float64
#  1   job             35191 non-null  int32
#  2   marital         35191 non-null  int32
#  3   education       35191 non-null  int32
#  4   default         35191 non-null  int32
#  5   housing         35191 non-null  int32
#  6   loan            35191 non-null  int32
#  7   contact         35191 non-null  int32
#  8   month           35191 non-null  int32
#  9   day_of_week     35191 non-null  int32
#  10  duration        35191 non-null  float64
#  11  campaign        35191 non-null  float64
#  12  pdays           35191 non-null  float64
#  13  previous        35191 non-null  float64
#  14  poutcome        35191 non-null  int32
#  15  emp.var.rate    35191 non-null  float64
#  16  cons.price.idx  35191 non-null  float64
#  17  cons.conf.idx   35191 non-null  float64
#  18  euribor3m       35191 non-null  float64
#  19  nr.employed     35191 non-null  float64
#  20  y               35191 non-null  int32
# dtypes: float64(10), int32(11)
# memory usage: 5.4 MB

# %%
# Collinerity

# %%
df.corr()
# Out:
#                      age       job   marital  education   default   housing  \
# age             1.000000 -0.017068 -0.391339  -0.100810  0.191650 -0.005481
# job            -0.017068  1.000000  0.032196   0.142276 -0.031551  0.007429
# marital        -0.391339  0.032196  1.000000   0.106524 -0.083036  0.013114
# education      -0.100810  0.142276  0.106524   1.000000 -0.193643  0.013684
# default         0.191650 -0.031551 -0.083036  -0.193643  1.000000 -0.013573
# housing        -0.005481  0.007429  0.013114   0.013684 -0.013573  1.000000
# loan           -0.005470 -0.012551  0.005215   0.004040  0.000379  0.043034
# contact         0.034949 -0.021976 -0.064229  -0.111536  0.130541 -0.083460
# month          -0.033322 -0.036375 -0.012347  -0.088112 -0.012908 -0.020868
# day_of_week    -0.026667  0.000461  0.006168  -0.020189 -0.006222  0.001514
# duration        0.002350 -0.009655  0.008908  -0.018460 -0.014650 -0.012088
# campaign        0.012661 -0.008950 -0.010911  -0.001182  0.023976 -0.009533
# pdays           0.003919 -0.026151 -0.047931  -0.055660  0.082024 -0.007679
# previous       -0.023000  0.019097  0.048029   0.043772 -0.102430  0.021128
# poutcome        0.019156  0.010545  0.004558   0.020323  0.022566 -0.013689
# emp.var.rate    0.076724 -0.000546 -0.099053  -0.057239  0.200035 -0.059672
# cons.price.idx  0.041188 -0.008605 -0.063982  -0.088736  0.161051 -0.079795
# cons.conf.idx   0.102309  0.046470 -0.033732   0.085875  0.045250 -0.036078
# euribor3m       0.088362 -0.001205 -0.107375  -0.049760  0.191639 -0.058273
# nr.employed     0.074024 -0.012123 -0.105631  -0.057947  0.186971 -0.044859
# y              -0.018712  0.023680  0.065019   0.084141 -0.112325  0.014756
#
#                     loan   contact     month  day_of_week  ...  campaign  \
# age            -0.005470  0.034949 -0.033322    -0.026667  ...  0.012661
# job            -0.012551 -0.021976 -0.036375     0.000461  ... -0.008950
# marital         0.005215 -0.064229 -0.012347     0.006168  ... -0.010911
# education       0.004040 -0.111536 -0.088112    -0.020189  ... -0.001182
# default         0.000379  0.130541 -0.012908    -0.006222  ...  0.023976
# housing         0.043034 -0.083460 -0.020868     0.001514  ... -0.009533
# loan            1.000000 -0.006583 -0.002360    -0.010540  ...  0.012387
# contact        -0.006583  1.000000  0.292888    -0.007963  ...  0.043346
# month          -0.002360  0.292888  1.000000     0.036091  ... -0.033930
# day_of_week    -0.010540 -0.007963  0.036091     1.000000  ... -0.052027
# duration       -0.010103 -0.030932  0.005964     0.029162  ... -0.056391
# campaign        0.012387  0.043346 -0.033930    -0.052027  ...  1.000000
# pdays          -0.000316  0.115729 -0.032824    -0.010453  ...  0.042013
# previous        0.000948 -0.214786  0.092750    -0.003034  ... -0.057070
# poutcome       -0.003561  0.126426 -0.069178     0.018569  ...  0.020495
# emp.var.rate    0.000089  0.399267 -0.136866     0.034717  ...  0.089170
# cons.price.idx -0.001684  0.604085  0.034901     0.006256  ...  0.066907
# cons.conf.idx  -0.009408  0.294226 -0.045754     0.041588  ... -0.005687
# euribor3m      -0.002267  0.402453 -0.080132     0.040821  ...  0.074401
# nr.employed     0.000298  0.264838 -0.182565     0.031069  ...  0.084552
# y              -0.007390 -0.145237 -0.022339     0.013408  ... -0.054333
#
#                    pdays  previous  poutcome  emp.var.rate  cons.price.idx  \
# age             0.003919 -0.023000  0.019156      0.076724        0.041188
# job            -0.026151  0.019097  0.010545     -0.000546       -0.008605
# marital        -0.047931  0.048029  0.004558     -0.099053       -0.063982
# education      -0.055660  0.043772  0.020323     -0.057239       -0.088736
# default         0.082024 -0.102430  0.022566      0.200035        0.161051
# housing        -0.007679  0.021128 -0.013689     -0.059672       -0.079795
# loan           -0.000316  0.000948 -0.003561      0.000089       -0.001684
# contact         0.115729 -0.214786  0.126426      0.399267        0.604085
# month          -0.032824  0.092750 -0.069178     -0.136866        0.034901
# day_of_week    -0.010453 -0.003034  0.018569      0.034717        0.006256
# duration       -0.073650  0.045443  0.037683     -0.051449        0.001015
# campaign        0.042013 -0.057070  0.020495      0.089170        0.066907
# pdays           1.000000 -0.574337 -0.466026      0.261180        0.064795
# previous       -0.574337  1.000000 -0.340525     -0.420214       -0.200726
# poutcome       -0.466026 -0.340525  1.000000      0.208268        0.225041
# emp.var.rate    0.261180 -0.420214  0.208268      1.000000        0.767824
# cons.price.idx  0.064795 -0.200726  0.225041      0.767824        1.000000
# cons.conf.idx  -0.072501 -0.088606  0.199721      0.309521        0.149247
# euribor3m       0.288878 -0.453340  0.197402      0.972566        0.681612
# nr.employed     0.369005 -0.502098  0.131326      0.901931        0.503970
# y              -0.378753  0.264278  0.148351     -0.335456       -0.141946
#
#                 cons.conf.idx  euribor3m  nr.employed         y
# age                  0.102309   0.088362     0.074024 -0.018712
# job                  0.046470  -0.001205    -0.012123  0.023680
# marital             -0.033732  -0.107375    -0.105631  0.065019
# education            0.085875  -0.049760    -0.057947  0.084141
# default              0.045250   0.191639     0.186971 -0.112325
# housing             -0.036078  -0.058273    -0.044859  0.014756
# loan                -0.009408  -0.002267     0.000298 -0.007390
# contact              0.294226   0.402453     0.264838 -0.145237
# month               -0.045754  -0.080132    -0.182565 -0.022339
# day_of_week          0.041588   0.040821     0.031069  0.013408
# duration            -0.003383  -0.059859    -0.078323  0.270210
# campaign            -0.005687   0.074401     0.084552 -0.054333
# pdays               -0.072501   0.288878     0.369005 -0.378753
# previous            -0.088606  -0.453340    -0.502098  0.264278
# poutcome             0.199721   0.197402     0.131326  0.148351
# emp.var.rate         0.309521   0.972566     0.901931 -0.335456
# cons.price.idx       0.149247   0.681612     0.503970 -0.141946
# cons.conf.idx        1.000000   0.373685     0.200588  0.040531
# euribor3m            0.373685   1.000000     0.943610 -0.345132
# nr.employed          0.200588   0.943610     1.000000 -0.403972
# y                    0.040531  -0.345132    -0.403972  1.000000
#
# [21 rows x 21 columns]

# %%
fig=plt.figure(figsize=(20,20))

sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Multicolinearity

# %%
cols=[]

for col in df.columns:
    if col!='y':
        cols.append(col)

# %%
cols
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x = df[cols]
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#           Features    vif_values
# 0              age     22.110947
# 1              job      2.101449
# 2          marital      5.690725
# 3        education      4.559769
# 4          default      1.411736
# 5          housing      2.212276
# 6             loan      1.208223
# 7          contact      2.942807
# 8            month      6.680441
# 9      day_of_week      3.100522
# 10        duration      3.223255
# 11        campaign      3.614700
# 12           pdays    174.947877
# 13        previous      6.071274
# 14        poutcome     34.953080
# 15    emp.var.rate     37.599362
# 16  cons.price.idx  37899.731335
# 17   cons.conf.idx    143.599901
# 18       euribor3m    322.738818
# 19     nr.employed  43131.557457

# %%
x=x.drop('nr.employed',axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#           Features  vif_values
# 0              age   22.104725
# 1              job    2.101203
# 2          marital    5.690042
# 3        education    4.558166
# 4          default    1.409152
# 5          housing    2.211962
# 6             loan    1.208175
# 7          contact    2.446251
# 8            month    5.781207
# 9      day_of_week    3.099651
# 10        duration    3.213497
# 11        campaign    3.601540
# 12           pdays  174.902760
# 13        previous    5.974480
# 14        poutcome   34.687553
# 15    emp.var.rate   22.295104
# 16  cons.price.idx  729.799050
# 17   cons.conf.idx  124.923275
# 18       euribor3m  130.932453

# %%
x=x.drop('cons.price.idx', axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#          Features  vif_values
# 0             age   20.976836
# 1             job    2.095641
# 2         marital    5.545216
# 3       education    4.502760
# 4         default    1.409124
# 5         housing    2.210296
# 6            loan    1.207604
# 7         contact    2.348362
# 8           month    5.722973
# 9     day_of_week    3.085422
# 10       duration    3.189065
# 11       campaign    3.585291
# 12          pdays   95.516915
# 13       previous    3.040768
# 14       poutcome   17.524845
# 15   emp.var.rate   16.714413
# 16  cons.conf.idx   82.725096
# 17      euribor3m   93.840224

# %%
x=x.drop('pdays', axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#          Features  vif_values
# 0             age   20.154425
# 1             job    2.092447
# 2         marital    5.426974
# 3       education    4.449333
# 4         default    1.409026
# 5         housing    2.206585
# 6            loan    1.207461
# 7         contact    2.274939
# 8           month    5.661826
# 9     day_of_week    3.073353
# 10       duration    3.177422
# 11       campaign    3.565919
# 12       previous    1.497517
# 13       poutcome    8.133931
# 14   emp.var.rate   12.917422
# 15  cons.conf.idx   42.661928
# 16      euribor3m   63.956416

# %%
x=x.drop('euribor3m',axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#          Features  vif_values
# 0             age   17.203602
# 1             job    2.086315
# 2         marital    5.227249
# 3       education    4.291909
# 4         default    1.408634
# 5         housing    2.198627
# 6            loan    1.207221
# 7         contact    2.266840
# 8           month    5.267354
# 9     day_of_week    3.033305
# 10       duration    3.170117
# 11       campaign    3.560035
# 12       previous    1.479775
# 13       poutcome    8.005489
# 14   emp.var.rate    1.547579
# 15  cons.conf.idx   32.073487

# %%
x=x.drop('cons.conf.idx', axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#         Features  vif_values
# 0            age   11.057212
# 1            job    2.077075
# 2        marital    4.373066
# 3      education    4.193003
# 4        default    1.407643
# 5        housing    2.162316
# 6           loan    1.203972
# 7        contact    2.242843
# 8          month    4.869014
# 9    day_of_week    2.969941
# 10      duration    3.098747
# 11      campaign    3.393848
# 12      previous    1.477224
# 13      poutcome    7.684058
# 14  emp.var.rate    1.532141

# %%
x=x.drop('age',axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#         Features  vif_values
# 0            job    2.054048
# 1        marital    4.352721
# 2      education    4.012540
# 3        default    1.322892
# 4        housing    2.112350
# 5           loan    1.200787
# 6        contact    2.241624
# 7          month    4.603319
# 8    day_of_week    2.889221
# 9       duration    2.982506
# 10      campaign    3.194005
# 11      previous    1.442162
# 12      poutcome    6.538542
# 13  emp.var.rate    1.531219

# %%
x=x.drop('poutcome', axis=1)

# %%
vif_data=pd.DataFrame()
vif_data['Features']=x.columns
vif_data['vif_values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#         Features  vif_values
# 0            job    2.034935
# 1        marital    4.136631
# 2      education    3.787748
# 3        default    1.313237
# 4        housing    2.080267
# 5           loan    1.198760
# 6        contact    2.225725
# 7          month    4.487451
# 8    day_of_week    2.804374
# 9       duration    2.829123
# 10      campaign    3.068970
# 11      previous    1.371509
# 12  emp.var.rate    1.522913

# %%
x
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 41181    0        1          6        0        2     0        0      7
# 41182   10        2          0        0        2     0        0      7
# 41184    1        1          5        0        0     0        0      7
# 41185    5        1          6        0        2     0        0      7
# 41186    9        1          5        0        0     0        0      7
#
#        day_of_week  duration  campaign  previous  emp.var.rate
# 0                1     261.0       1.0       0.0           1.1
# 1                1     149.0       1.0       0.0           1.1
# 2                1     226.0       1.0       0.0           1.1
# 3                1     151.0       1.0       0.0           1.1
# 4                1     307.0       1.0       0.0           1.1
# ...            ...       ...       ...       ...           ...
# 41181            0     281.0       1.0       0.0          -1.1
# 41182            0     112.0       1.0       1.0          -1.1
# 41184            0     383.0       1.0       0.0          -1.1
# 41185            0     189.0       2.0       0.0          -1.1
# 41186            0     442.0       1.0       0.0          -1.1
#
# [35191 rows x 13 columns]

# %%
y=df['y']

# %%
# Model building

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.3, random_state=100)

# %%
x_train
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 19199    9        2          6        0        2     2        0      1
# 31063    0        0          5        0        0     0        0      6
# 6943     1        1          7        1        0     0        1      6
# 6909     7        1          3        1        0     0        1      6
# 5313     1        1          0        0        2     0        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 19639    9        2          5        0        2     2        0      1
# 19168    1        1          7        1        0     0        0      1
# 84       9        2          6        0        0     2        1      6
# 13954    1        1          2        1        0     2        0      3
# 16431    7        2          2        0        2     0        1      3
#
#        day_of_week  duration  campaign  previous  emp.var.rate
# 19199            4     455.0       3.0       0.0           1.4
# 31063            4     194.0       1.0       1.0          -1.8
# 6943             2     361.0       1.0       0.0           1.1
# 6909             2     267.0       1.0       0.0           1.1
# 5313             0     469.0       2.0       0.0           1.1
# ...            ...       ...       ...       ...           ...
# 19639            2     414.0       2.0       0.0           1.4
# 19168            3     371.0       3.0       0.0           1.4
# 84               1      20.0       1.0       0.0           1.1
# 13954            0     196.0       2.0       0.0           1.4
# 16431            4     108.0       2.0       0.0           1.4
#
# [24633 rows x 13 columns]

# %%
y_train
# Out:
# 19199    1
# 31063    0
# 6943     0
# 6909     0
# 5313     0
#         ..
# 19639    0
# 19168    0
# 84       0
# 13954    0
# 16431    0
# Name: y, Length: 24633, dtype: int32

# %%
x_test
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 6087     1        1          2        0        0     0        1      6
# 25150    9        0          5        0        2     2        0      7
# 12529    9        2          5        0        2     2        0      3
# 40722    0        2          6        0        2     2        0      9
# 32826    1        2          2        0        2     0        0      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 35923    0        1          6        0        0     0        0      6
# 2516     9        1          5        0        0     2        1      6
# 24872    0        1          6        0        2     0        0      7
# 1690     9        1          5        0        0     0        1      6
# 27630    0        1          3        0        2     0        0      7
#
#        day_of_week  duration  campaign  previous  emp.var.rate
# 6087             3     155.0       1.0       0.0           1.1
# 25150            3     124.0       1.0       0.0          -0.1
# 12529            1     554.0       1.0       0.0           1.4
# 40722            3     194.0       1.0       0.0          -1.1
# 32826            1     333.0       1.0       0.0          -1.8
# ...            ...       ...       ...       ...           ...
# 35923            1      90.0       1.0       0.0          -1.8
# 2516             3      95.0       1.0       0.0           1.1
# 24872            3      71.0       2.0       0.0          -0.1
# 1690             0     114.0       1.0       0.0           1.1
# 27630            0       9.0       5.0       0.0          -0.1
#
# [10558 rows x 13 columns]

# %%
y_test
# Out:
# 6087     0
# 25150    0
# 12529    0
# 40722    1
# 32826    0
#         ..
# 35923    0
# 2516     0
# 24872    0
# 1690     0
# 27630    0
# Name: y, Length: 10558, dtype: int32

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 6087     0
# 25150    0
# 12529    0
# 40722    1
# 32826    0
#         ..
# 35923    0
# 2516     0
# 24872    0
# 1690     0
# 27630    0
# Name: y, Length: 10558, dtype: int32

# %%
# Model evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
ac = accuracy_score(y_pred, y_test)

# %%
ac
# Out:
# 0.9264065163856791

# %%
cm = confusion_matrix(y_pred, y_test)
cm
# Out:
# array([[9607,  628],
#        [ 149,  174]], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV

# Hyperparameter tuning using GridSearchCV
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5)
grid_search.fit(x_train, y_train)

print("Best parameters:", grid_search.best_params_)

# Training the model with best parameters
best_model = grid_search.best_estimator_
best_model.fit(x_train, y_train)

# Predictions using the best model
y_pred_best = best_model.predict(x_test)

# Model evaluation with best model
ac_best = accuracy_score(y_pred_best, y_test)
print("Accuracy with best model:", ac_best)

# Confusion matrix with best model
cm_best = confusion_matrix(y_pred_best, y_test)
print("Confusion matrix with best model:")
print(cm_best)

# Additional evaluation metrics
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test, y_pred_best)
recall = recall_score(y_test, y_pred_best)
f1 = f1_score(y_test, y_pred_best)

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# G:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
